# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
print("All libraries imported successfully!")
# Out:
# All libraries imported successfully!

# %%
import requests
from bs4 import BeautifulSoup

url = "https://books.toscrape.com/"

response = requests.get(url)

soup = BeautifulSoup(response.text, "html.parser")

books = soup.find_all("h3")

for book in books:
    print(book.text)
# Out:
# A Light in the ...
# Tipping the Velvet
# Soumission
# Sharp Objects
# Sapiens: A Brief History ...
# The Requiem Red
# The Dirty Little Secrets ...
# The Coming Woman: A ...
# The Boys in the ...
# The Black Maria
# Starving Hearts (Triangular Trade ...
# Shakespeare's Sonnets
# Set Me Free
# Scott Pilgrim's Precious Little ...
# Rip it Up and ...
# Our Band Could Be ...
# Olio
# Mesaerion: The Best Science ...
# Libertarianism for Beginners
# It's Only the Himalayas

# %%
import requests
from bs4 import BeautifulSoup

url = "https://books.toscrape.com/"

response = requests.get(url)

print(response.status_code)
# Out:
# 200

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://books.toscrape.com/"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

books = soup.find_all("article", class_="product_pod")

book_data = []

for book in books:
    title = book.h3.a["title"]
    price = book.find("p", class_="price_color").text
    rating = book.find("p")["class"][1]

    book_data.append([title, price, rating])

df = pd.DataFrame(book_data, columns=["Title", "Price", "Rating"])

print(df.head())
# Out:
#                                    Title    Price Rating
# 0                   A Light in the Attic  Â£51.77  Three
# 1                     Tipping the Velvet  Â£53.74    One
# 2                             Soumission  Â£50.10    One
# 3                          Sharp Objects  Â£47.82   Four
# 4  Sapiens: A Brief History of Humankind  Â£54.23   Five

# %%
df.to_csv("books_data.csv", index=False)

print("CSV file saved successfully!")
# Out:
# CSV file saved successfully!

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\Abish
# ['-1.14-windows.xml', '.antigravity-ide', '.bash_history', '.cache', '.codex', '.config', '.copilot', '.docker', '.eclipse', '.gemini', '.gitconfig', '.idlerc', '.ipynb_checkpoints', '.ipython', '.jupyter', '.lesshst', '.m2', '.node_repl_history', '.p2', '.redhat', '.securecoder', '.sts4', '.vscode', '.vscode-shared', 'AppData', 'Application Data', 'archive.zip', 'books_data.csv', 'Contacts', 'Cookies', 'CrossDevice', 'Documents', 'Downloads', 'eclipse', 'eclipse-workspace', 'error.txt', 'Favorites', 'Links', 'Local Settings', 'Music', 'My Documents', 'netflix_titles.csv', 'NetHood', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{c04a3068-9501-11ef-9843-d4e98a3a3d0f}.TM.blf', 'NTUSER.DAT{c04a3068-9501-11ef-9843-d4e98a3a3d0f}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{c04a3068-9501-11ef-9843-d4e98a3a3d0f}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'OneDrive', 'package thursday06.java', 'package-lock.json', 'PrintHood', 'Recent', 'Saved Games', 'Searches', 'SendTo', 'Start Menu', 'Task1_WebScraping.ipynb', 'Task2_EDA_Netflix.ipynb', 'Task2_EDA_Netflix.ipynbp', 'Task3_DataVisualization.ipynb', 'Templates', 'Untitled.ipynb', 'Videos', 'WPS Cloud Files', 'WPSDrive']
